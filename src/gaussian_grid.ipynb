# %%
import bourgan
from bourgan.gan import BourGAN
from bourgan.visualizer import *

# %%
bourGAN = BourGAN()
# Out:
# scale factor: 1.1020235528780773

# %%
plot_outputdata(bourGAN.dataset.data)

# %%
plot_sampler(bourGAN.z_sampler, 1000, tsne=False, kde=False, dim1=0, dim2=1, rotate=True, origin_data=False)

# %%
visualize_G(bourGAN, 1000,)
# Out:
# (array([[-4.0794855 , -4.07295986],
#         [-3.89291742, -4.09823474],
#         [-4.22468604, -3.70698368],
#         ...,
#         [ 3.95835621,  3.94612836],
#         [ 4.1424835 ,  3.9624724 ],
#         [ 3.97491726,  4.07808378]]), array([[ 0.09856918, -0.03091901],
#         [ 0.07324819, -0.17222509],
#         [ 0.08491166, -0.01457286],
#         ...,
#         [ 0.00036746,  0.02897488],
#         [ 0.00434182,  0.02716258],
#         [ 0.06129657,  0.20901519]], dtype=float32))

# %%
bourGAN.train()
# Out:
# training start
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-075fca9d794c> in <module>()
# ----> 1 bourGAN.train()
#
# ~/Documents/bourgan/src/bourgan/gan.py in train(self, iters)
#      87                 d_real_data = real_samples.to(dtype=torch.float32, device=self.device)
#      88
# ---> 89                 d_real_decision = self.D(d_real_data)
#      90                 labels = torch.ones(d_real_decision.shape, dtype=torch.float32, device=self.device)
#      91
#
# ~/anaconda3/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# ~/Documents/bourgan/src/bourgan/NN/MLP.py in forward(self, x)
#      25         x = F.leaky_relu(self.map1(x), 0.1)
#      26         x = F.leaky_relu(self.map2(x), 0.1)
# ---> 27         return torch.sigmoid(self.map3(x))
#
# NameError: name 'torch' is not defined
