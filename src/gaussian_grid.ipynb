# %%
import bourgan
from bourgan.gan import BourGAN
from bourgan.visualizer import *

# %%
bourGAN = BourGAN()
# Out:
# scale factor: 1.043020282348038

# %%
plot_outputdata(bourGAN.dataset.data)

# %%
plot_sampler(bourGAN.z_sampler, 1000, tsne=False, kde=False, dim1=0, dim2=1, rotate=True, origin_data=False)

# %%
visualize_G(bourGAN, 1000,)
# Out:
# (array([[-3.95922199, -3.98875816],
#         [-3.94407889, -4.00910543],
#         [-3.96468742, -3.89729298],
#         ...,
#         [ 3.89275675,  3.92282898],
#         [ 4.0253234 ,  3.90687202],
#         [ 4.12040628,  3.89409709]]), array([[ 0.05665261,  0.09923147],
#         [ 0.083252  ,  0.0918716 ],
#         [-0.01901529,  0.14369008],
#         ...,
#         [ 0.11805037,  0.07757895],
#         [ 0.11484312,  0.02882744],
#         [ 0.1645159 ,  0.06297844]], dtype=float32))

# %%
bourGAN.train()
# Out:
# training start
# Iteration 0: D_loss(real/fake): 0.6687711477279663/0.6755057573318481 G_loss: 2.9929347038269043
# Iteration 100: D_loss(real/fake): 0.6619418263435364/0.6692512035369873 G_loss: 0.8317402005195618
# Iteration 200: D_loss(real/fake): 0.6899544596672058/0.6909152269363403 G_loss: 0.7954617738723755
# Iteration 300: D_loss(real/fake): 0.694912314414978/0.6901121139526367 G_loss: 0.8145176768302917
# Iteration 400: D_loss(real/fake): 0.7071452140808105/0.654109537601471 G_loss: 0.8401364684104919
# Iteration 500: D_loss(real/fake): 0.6956064105033875/0.6963000297546387 G_loss: 0.7982202768325806
# Iteration 600: D_loss(real/fake): 0.687298059463501/0.7049167156219482 G_loss: 0.7731463313102722
# Iteration 700: D_loss(real/fake): 0.7014842629432678/0.6740245819091797 G_loss: 0.7689501643180847
# Iteration 800: D_loss(real/fake): 0.6865701079368591/0.7005026936531067 G_loss: 0.7618622183799744
# Iteration 900: D_loss(real/fake): 0.6930989027023315/0.6900871396064758 G_loss: 0.7651063799858093
# Iteration 1000: D_loss(real/fake): 0.7068791389465332/0.6712587475776672 G_loss: 0.7579156756401062
# Iteration 1100: D_loss(real/fake): 0.6862391829490662/0.7080787420272827 G_loss: 0.7601199150085449
# Iteration 1200: D_loss(real/fake): 0.7105393409729004/0.6704267263412476 G_loss: 0.7985593676567078
# Iteration 1300: D_loss(real/fake): 0.6752603054046631/0.6986538171768188 G_loss: 0.7737770080566406
# Iteration 1400: D_loss(real/fake): 0.727128267288208/0.694497287273407 G_loss: 0.7710732817649841
# Iteration 1500: D_loss(real/fake): 0.6941608190536499/0.6996915340423584 G_loss: 0.7891229391098022
# Iteration 1600: D_loss(real/fake): 0.6981185674667358/0.674127459526062 G_loss: 0.7648018598556519
