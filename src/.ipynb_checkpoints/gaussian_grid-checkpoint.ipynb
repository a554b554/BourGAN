# %%
import bourgan
from bourgan.gan import BourGAN
from bourgan.visualizer import *

# %%
bourGAN = BourGAN()
# Out:
# scale factor: 0.9565645490166172
# using gpu!!

# %%
plot_outputdata(bourGAN.dataset.data)

# %%
plot_sampler(bourGAN.z_sampler, 1000, tsne=False, kde=False, dim1=0, dim2=1, rotate=True, origin_data=False)

# %%
bourGAN.train()
# Out:
# training start
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-075fca9d794c> in <module>()
# ----> 1 bourGAN.train()
#
# ~/Documents/bourgan/src/bourgan/gan.py in train(self, iters)
#      75         for ep in pbar:
#      76             if ep % self.show_step == 0:
# ---> 77                 real_data, fake_data = visualize_G(self, 5000, dim1=0, dim2=1)
#      78                 eppp = ep // self.show_step
#      79
#
# ~/Documents/bourgan/src/bourgan/visualizer.py in visualize_G(nets, N, show_dataset, kde, dim1, dim2)
#      20
#      21     if nets.use_gpu:
# ---> 22         in_data = Variable(uni).cuda()
#      23     else:
#      24         in_data = Variable(uni)
#
# NameError: name 'Variable' is not defined
